# %% [markdown]
# # Line Graph

# %%
import matplotlib.pyplot as plt

# %%
#Using Lists
x = [1,2,3,5]
y = [8,3,7,9]
plt.plot(x,y,c = '#fdb147',marker = '*')
plt.xlabel('X - Axis')
plt.ylabel('Y-Axis')
plt.title('My Line Graph')
plt.show()

# %%
x = np.linspace(0,10,6)
y = np.zeros(6)
plt.plot(x,y,'o')

# %%
# Example - 2

# %%
overs = [0,4,8,12,16,20]
team1 = [0,30,67,98,123,145]
team2 = [0,27,75,103,110,137]
plt.plot(overs,team1,marker = '*',c = 'r',label = 'Team 1')
plt.plot(overs,team2,marker = '+',c = 'g',label = 'Team 2')
plt.title(' Analysis of Cricket Match')
plt.xlabel('Overs')
plt.ylabel('Runs')
plt.legend()
plt.show()

# %%
# Using Random Values

# %%
import numpy as np
overs1  = np.arange(0,21,4)
print(overs1)
overs2 = np.linspace(0,20,6,dtype = 'int32')
print(overs2)
team1 = np.random.randint(0,150,6)
team1.sort()
print(team1)
team2 = np.random.randint(0,150,6)
team2.sort()
print(team2)
plt.plot(overs1,team1,marker = '*',c = 'r',label = 'Team 1')
plt.plot(overs1,team2,marker = '+',c = 'g',label = 'Team 2')
plt.title(' Analysis of Cricket Match')
plt.xlabel('Overs')
plt.ylabel('Runs')
plt.grid()
plt.legend()
plt.show()
# Out:
# [ 0  4  8 12 16 20]
# [ 0  4  8 12 16 20]
# [ 17  41  92 112 126 127]
# [ 32  48  57 124 132 143]

# %%
import random
import matplotlib.pyplot as plt
fig = plt.figure()

x1 = np.random.randint(0,10,5)
y1 = np.random.randint(0,10,5)
x2 = np.random.randint(0,10,5)
y2 = np.random.randint(0,10,5)
x3 = np.random.randint(0,10,5)
y3 = np.random.randint(0,10,5)
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(212)

ax1.plot(x1,y1)
ax2.plot(x2,y2)
ax3.plot(x3,y3)

# %%
x = np.arange(0,3*np.pi,0.1)
y=np.sin(x)
plt.plot(x,y)

# %% [markdown]
# # Subplots for various equation graphs

# %%
import matplotlib.pyplot as plt 
import numpy as np 
  
# function to generate coordinates 
def create_plot(ptype): 
    # setting the x-axis vaues 
    x = np.arange(-10, 10, 0.01) 
      
    # setting the y-axis values 
    if ptype == 'linear': 
        y = x 
    elif ptype == 'quadratic': 
        y = x**2
    elif ptype == 'cubic': 
        y = x**3
    elif ptype == 'quartic': 
        y = x**4
              
    return(x, y) 
  
# setting a style to use 
plt.style.use('fivethirtyeight') 
  
# create a figure 
fig = plt.figure() 
  
# define subplots and their positions in figure 
plt1 = fig.add_subplot(221) 
plt2 = fig.add_subplot(222) 
plt3 = fig.add_subplot(223) 
plt4 = fig.add_subplot(224) 
  
# plotting points on each subplot 
x, y = create_plot('linear') 
plt1.plot(x, y, color ='r') 
plt1.set_title('$y_1 = x$') 
  
x, y = create_plot('quadratic') 
plt2.plot(x, y, color ='b') 
plt2.set_title('$y_2 = x^2$') 
  
x, y = create_plot('cubic') 
plt3.plot(x, y, color ='g') 
plt3.set_title('$y_3 = x^3$') 
  
x, y = create_plot('quartic') 
plt4.plot(x, y, color ='k') 
plt4.set_title('$y_4 = x^4$') 
  
# adjusting space between subplots 
fig.subplots_adjust(hspace=.5,wspace=0.5) 
  
# function to show the plot 
plt.show()

# %% [markdown]
# # Scatter Plot

# %%
a = [1,2,3,4,5]
b= [2,3,4,5,6]
plt.scatter(a,b,c=[10,20,30,2,4],s = 30)
plt.plot(a,b,c ='k')
plt.show()

# %%
# Example 2

# %%
import random
randomlist1 = []
randomlist2 = []
for i in range(0,100):
    n= random.randint(20,30)
    m= random.randint(10,300)
    randomlist1.append(n)
    randomlist2.append(m)
print(randomlist1)
print(randomlist2)

# %%
plt.scatter(randomlist1,randomlist2,
           c = randomlist1, s= randomlist2,
           alpha = 0.6)
plt.title(' My Scatter Plot')
plt.xlabel('Random Values taken on x')
plt.ylabel('Random Values taken on y')
plt.show()
plt.savefig('Scatterplot123.png')

# %%
plt.plot(randomlist1,randomlist2)
plt.show()

# %% [markdown]
# # Bar Graph

# %%
import numpy as np  # Importing numpy for getting a range
import matplotlib.pyplot as plt 
height = [150,160,132,148]  # Height give
weight = [23,45,67,34]   #Weight given
abc = ['r','g','b','k']   # COlors 1
cba = ['pink','c','y','m']   # colors 2
n =4  # Number of people
index = np.arange(n)  # One variable which has to be considered for x axis
bar_width =0.4 # I will specify a variable for width
rect1 = plt.bar(index,height,bar_width,
                color = abc,label = 'Height')
# Plot first graph with index as x - axis
rect2 = plt.bar(index+bar_width,weight,bar_width,
                color = cba,label = 'Weight') 
# plot second graph with index + bar_width as x-axis
plt.xticks(index+bar_width,['A','B','C','D'])
# LAbelling the X axis properly
plt.legend() # showing the labels
plt.show()

# %%
index = np.arange(4)
index
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# # Pie Chart

# %%
days = [1,1,3,2]
languages = [' English','Tamil','Maths','Science']
abc = ['r' ,'g','b','c']
plt.pie(days,explode = [0,0.2,0,0],labels = languages,
       colors = abc,autopct = '%1.1f%%',shadow = True,
        startangle =90)
plt.legend(loc = 2)
plt.show()

# %%
import numpy as np
N = 150
r = 2 * np.random.rand(N)
theta = 2 * np.pi * np.random.rand(N)
area = 200 * r**2
colors = theta

fig = plt.figure()
ax = fig.add_subplot(111, projection='polar')
c = ax.scatter(theta, r, c=colors, s=area, cmap='hot', alpha=1)
